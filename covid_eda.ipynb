# %%
import pandas as pd

# %%
try:
    covid_data = pd.read_csv("covid_data.csv")
    if not covid_data.empty:
        print("Let's EDA")
    else:
        print("DataFrame is empty")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Let's EDA

# %% [markdown]
# **Questions**
# - Total deaths
# - Total deaths by Country

# %%
covid_data.head(10)
# Out:
#      #  Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0  NaN  North America  131,889,132       NaN   1,695,941        NaN
# 1  NaN           Asia  221,500,265       NaN   1,553,662        NaN
# 2  NaN         Europe  253,406,198       NaN   2,101,824        NaN
# 3  NaN  South America   70,200,879       NaN   1,367,332        NaN
# 4  NaN        Oceania   14,895,771       NaN      33,015        NaN
# 5  NaN         Africa   12,860,924       NaN     258,892        NaN
# 6  NaN            NaN          721       NaN          15        NaN
# 7  NaN          World  704,753,890       0.0   7,010,681        0.0
# 8  1.0            USA  111,820,082       NaN   1,219,487        NaN
# 9  2.0          India   45,035,393       NaN     533,570        NaN
#
#   TotalRecovered  NewRecovered ActiveCases Serious,Critical  ...  \
# 0    127,665,129         350.0   2,528,062            6,095  ...
# 1    205,673,091           NaN  14,273,512           14,733  ...
# ...

# %%
covid_eda=covid_data.drop('#',axis=1)
covid_eda.head(10)
# Out:
#    Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  North America  131,889,132       NaN   1,695,941        NaN    127,665,129
# 1           Asia  221,500,265       NaN   1,553,662        NaN    205,673,091
# 2         Europe  253,406,198       NaN   2,101,824        NaN    248,754,104
# 3  South America   70,200,879       NaN   1,367,332        NaN     66,683,585
# 4        Oceania   14,895,771       NaN      33,015        NaN     14,752,388
# 5         Africa   12,860,924       NaN     258,892        NaN     12,090,808
# 6            NaN          721       NaN          15        NaN            706
# 7          World  704,753,890       0.0   7,010,681        0.0    675,619,811
# 8            USA  111,820,082       NaN   1,219,487        NaN    109,814,428
# 9          India   45,035,393       NaN     533,570        NaN            NaN
#
#    NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  ...  \
# ...

# %%
covid_total = covid_eda.iloc[7]
covid_total
# Out:
# Country,Other                World
# TotalCases             704,753,890
# NewCases                       0.0
# TotalDeaths              7,010,681
# NewDeaths                      0.0
# TotalRecovered         675,619,811
# NewRecovered                 790.0
# ActiveCases             22,123,398
# Serious,Critical            34,794
# Tot Cases/1M pop            90,413
# Deaths/1M pop                899.4
# TotalTests                     NaN
# Tests/\n1M pop                 NaN
# Population                     NaN
# Continent                      All
# 1 Caseevery X ppl              NaN
# 1 Deathevery X ppl             NaN
# 1 Testevery X ppl              NaN
# New Cases/1M pop               NaN
# New Deaths/1M pop              NaN
# Active Cases/1M pop            NaN
# Name: 7, dtype: object

# %%
continent=covid_eda.iloc[0:6]
continent
# Out:
#    Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  North America  131,889,132       NaN   1,695,941        NaN    127,665,129
# 1           Asia  221,500,265       NaN   1,553,662        NaN    205,673,091
# 2         Europe  253,406,198       NaN   2,101,824        NaN    248,754,104
# 3  South America   70,200,879       NaN   1,367,332        NaN     66,683,585
# 4        Oceania   14,895,771       NaN      33,015        NaN     14,752,388
# 5         Africa   12,860,924       NaN     258,892        NaN     12,090,808
#
#    NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  ... TotalTests  \
# 0         350.0   2,528,062            6,095              NaN  ...        NaN
# 1           NaN  14,273,512           14,733              NaN  ...        NaN
# 2         474.0   2,550,270            4,453              NaN  ...        NaN
# 3           NaN   2,149,962            8,953              NaN  ...        NaN
# ...

# %%
covid_eda = covid_eda.iloc[8:]
covid_eda.head()
# Out:
#    Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 8            USA  111,820,082       NaN   1,219,487        NaN    109,814,428
# 9          India   45,035,393       NaN     533,570        NaN            NaN
# 10        France   40,138,560       NaN     167,642        NaN     39,970,918
# 11       Germany   38,828,995       NaN     183,027        NaN     38,240,600
# 12        Brazil   38,743,918       NaN     711,380        NaN     36,249,161
#
#     NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  ...  \
# 8            NaN     786,167              940          333,985  ...
# 9            NaN         NaN              NaN           32,016  ...
# 10           NaN           0              NaN          612,013  ...
# 11           NaN     405,368              NaN          462,891  ...
# 12           NaN   1,783,377              NaN          179,908  ...
#
#        TotalTests Tests/\n1M pop     Population      Continent  \
# ...

# %%
covid_eda.isna().sum()
# Out:
# Country,Other            0
# TotalCases               0
# NewCases               238
# TotalDeaths              5
# NewDeaths              238
# TotalRecovered          48
# NewRecovered           233
# ActiveCases             47
# Serious,Critical       179
# Tot Cases/1M pop         9
# Deaths/1M pop           14
# TotalTests              26
# Tests/\n1M pop          26
# Population              10
# Continent                3
# 1 Caseevery X ppl       10
# 1 Deathevery X ppl      15
# 1 Testevery X ppl       26
# New Cases/1M pop       239
# New Deaths/1M pop      239
# Active Cases/1M pop     36
# dtype: int64

# %%
covid_eda = covid_eda.fillna(0)

# %%
covid_eda.isna().sum()
# Out:
# Country,Other          0
# TotalCases             0
# NewCases               0
# TotalDeaths            0
# NewDeaths              0
# TotalRecovered         0
# NewRecovered           0
# ActiveCases            0
# Serious,Critical       0
# Tot Cases/1M pop       0
# Deaths/1M pop          0
# TotalTests             0
# Tests/\n1M pop         0
# Population             0
# Continent              0
# 1 Caseevery X ppl      0
# 1 Deathevery X ppl     0
# 1 Testevery X ppl      0
# New Cases/1M pop       0
# New Deaths/1M pop      0
# Active Cases/1M pop    0
# dtype: int64

# %%
covid_eda
# Out:
#     Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 8             USA  111,820,082       0.0   1,219,487        0.0
# 9           India   45,035,393       0.0     533,570        0.0
# 10         France   40,138,560       0.0     167,642        0.0
# 11        Germany   38,828,995       0.0     183,027        0.0
# 12         Brazil   38,743,918       0.0     711,380        0.0
# ..            ...          ...       ...         ...        ...
# 242        Total:   70,200,879       0.0   1,367,332        0.0
# 243        Total:   14,895,771       0.0      33,015        0.0
# 244        Total:   12,860,924       0.0     258,892        0.0
# 245        Total:          721       0.0          15        0.0
# 246        Total:  704,753,890       0.0   7,010,681        0.0
#
#     TotalRecovered  NewRecovered ActiveCases Serious,Critical  \
# 8      109,814,428           0.0     786,167              940
# 9                0           0.0           0                0
# ...

# %%
covid_eda.duplicated().sum()
# Out:
# 0
